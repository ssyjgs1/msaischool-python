# %% [markdown]
# # 04. 레이아웃(Layout) - 02) 박스 레이아웃
# - URL from : https://wikidocs.net/21945
# - 박스 레이아웃 클래스를 이용하면 훨씬 유연하고 실용적인 레이아웃을 짤 수 있다.
# - `QHBoxLayout`, `QVBoxLayout`은 여러 위젯을 수평으로 정렬하는 레이아웃 클래스다.
# - `QHBoxLayout`, `QVBoxLayout` 생성자는 수평, 수직의 박스를 하나 만드는데, 다른 레이아웃 박스를 넣을 수도 있고, 위젯을 배치할 수도 있다.
# - 본 예제에서는 위젯의 가운데 아래 부분에 2개의 버튼을 배치하기 위해, 수평, 수직의 박스를 하나씩 사용해보자.
# - 필요한 공간을 만들기 위해 `addStretch()` 메소드를 사용하고, `stretch factor`를 조절해보자.

# %% [markdown]
# ## 예제 스크립트

# %% [markdown]
# - 창의 가운데 아래에 2개의 버튼을 배치시켜보자.
# - 2개의 버튼은 창의 크기를 변화시켜도 같은 자리에 위치한다.

# %%
# 필요한 라이브러리 import
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QHBoxLayout, QVBoxLayout

class MyApp(QWidget) :
    def __init__(self) :
        super().__init__()
        self.initUI()

    def initUI(self) :
        okButton = QPushButton('OK')
        cancelButton = QPushButton('Cancel')

        hbox = QHBoxLayout()
        hbox.addStretch(1)
        hbox.addWidget(okButton)
        hbox.addWidget(cancelButton)
        hbox.addStretch(1)

        vbox = QVBoxLayout()
        vbox.addStretch(3)
        vbox.addLayout(hbox)
        vbox.addStretch(1)

        self.setLayout(vbox)

        self.setWindowTitle('Box Layout')
        self.setGeometry(300, 300, 300, 200)
        self.show()

if __name__ == '__main__' :
    app = QApplication(sys.argv)
    ex = MyApp()
    sys.exit(app.exec_())

# %% [markdown]
# ## 예제 스크립트 설명
# - 2개의 버튼을 만든다.

# %%
okButton = QPushButton('OK')
cancelButton = QPushButton('Cancel')

# %% [markdown]
# - 수평 박스를 하나 만들고, 2개의 버튼과 양 쪽에 빈 공간을 추가한다.
# - 이 `addStretch()` 메소드는 신축성있는 빈 공간을 제공한다.
# - 두 버튼 양쪽의 `stretch factor`가 1로 같기 때문에 이 두 빈 공간의 크기는 창의 크기가 변화해도 항상 같다.

# %%
hbox = QHBoxLayout()
hbox.addStretch(1)
hbox.addWidget(okButton)
hbox.addWidget(cancelButton)
hbox.addStretch(1)

# %% [markdown]
# - 수평 박스를 수직 박스에 넣어준다.
# - 수직 박스의 `stretch factor`는 수평 박스를 아래쪽으로 밀어내서 2개의 버튼을 창의 아래쪽에 위치하도록 한다.
# - 이 때에도 수평 박스 위와 아래의 빈 공간의 크기는 항상 3:1을 유지한다. `stretch factor`를 다양하게 바꿔볼 수 있다.

# %%
vbox = QVBoxLayout()
vbox.addStretch(3)
vbox.addLayout(hbox)
vbox.addStretch(1)

# %% [markdown]
# - 최종적으로 수직 박스를 창의 메인 레이아웃으로 설정해준다.

# %%
self.setLayout(vbox)
