# %% [markdown]
# # 03. 기초(Basics) - 10) 스타일 꾸미기
# - URL from : https://wikidocs.net/33889
# - ```setStyleSheet()```를 이용하면 앱 안의 다양한 구성 요소들의 스타일을 자유로이 꾸밀 수 있다.

# %% [markdown]
# ## 예제 스크립트

# %%
# 필요한 라이브러리 import
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QVBoxLayout

# %%
class MyApp(QWidget) :
    def __init__(self) :
        super().__init__()
        self.initUI()

    def initUI(self) :
        lbl_red = QLabel('Red')
        lbl_green = QLabel('Green')
        lbl_blue = QLabel('Blue')

        lbl_red.setStyleSheet('color : red;' 'border-style : solid;' 'border0width : 2px;' 'border-color : #FA8072;' 'border-radius : 3px;')
        lbl_green.setStyleSheet('color : green;' 'background-color : #7FFFD4;')
        lbl_blue.setStyleSheet('color : blue;' 'background-color : #87CEFA;' 'border-style : dashed;' 'border-width : 3px;' 'border-color : #E90FF;')

        vbox = QVBoxLayout()
        vbox.addWidget(lbl_red)
        vbox.addWidget(lbl_green)
        vbox.addWidget(lbl_blue)

        self.setLayout(vbox)

        self.setWindowTitle('Stylesheet')
        self.setGeometry(300, 300, 300, 200)
        self.show()

# 실행문
if __name__ == '__main__' :
    app = QApplication(sys.argv)
    ex = MyApp()
    sys.exit(app.exec_())

# %% [markdown]
# ## 예제 스크립트 설명

# %% [markdown]
# - ```QLabel``` 클래스를 이용해서 3개의 라벨 위젯을 만든다.
# - 라벨 텍스트는 각각 'Red', 'Green', 'Blue'로 설정한다.

# %%
lbl_red = QLabel('Red')
lbl_green = QLabel('Green')
lbl_blue = QLabel('Blue')

# %% [markdown]
# - ```setStyleSheet()``` 메소드를 이용해서 글자색을 빨간색(red)으로, 경계선을 실선(solid)으로, 경계선 두께를 2px로, 경계선 색을 #FA8072로, 경계선의 모서리를 3px만큼 둥글게 설정한다.

# %%
lbl_red.setStyleSheet('color : red;' 'border-style : solid;' 'border0width : 2px;' 'border-color : #FA8072;' 'border-radius : 3px;')

# %% [markdown]
# - 마찬가지로, `lbl_green` 라벨의 글자색을 녹색(green)으로, 배경색을 #7FFFD4로 설정한다.

# %%
lbl_green.setStyleSheet('color : green;' 'background-color : #7FFFD4;')

# %% [markdown]
# - `lbl_blue` 라벨의 글자색을 파란색(blue)으로, 배경색을 #87CEFA로, 경계선을 대쉬 스타일로, 경계선 두께를 3px로, 경계선 색을 #1E90FF로 설정한다.

# %%
lbl_blue.setStyleSheet('color : blue;' 'background-color : #87CEFA;' 'border-style : dashed;' 'border-width : 3px;' 'border-color : #E90FF;')

# %% [markdown]
# - 수직 박스 레이아웃(`QVBoxLayout()`)을 이용해서 3개의 라벨 위젯을 수직으로 배치한다.

# %%
vbox = QVBoxLayout()
vbox.addWidget(lbl_red)
vbox.addWidget(lbl_green)
vbox.addWidget(lbl_blue)

self.setLayout(vbox)
